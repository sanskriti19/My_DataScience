# %%
def one_dict(list_dict):
    keys = list_dict[0].keys()
    out_dict = {key:[] for key in keys}
    for dict_ in list_dict:
        for key,value in dict_.items():
            out_dict[key].append(value)
    return out_dict

# %%
# !pip install nba_api

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dict_ = {"a":[11,21,31], "b":[12,22,32]}

# %%
#pandas is an API. We are communicating with pandas API. dataframe is used to communicate with pandas API. 
#Hence "dataframe" is an instance(in API lingo ).

df= pd.DataFrame(dict_)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# here head is used to communicate with API to displa first 5 rows

df.head()
# Out:
#     a   b
# 0  11  12
# 1  21  22
# 2  31  32

# %%
#here API calculates the mean

df.mean()
# Out:
# a    21.0
# b    22.0
# dtype: float64

# %%
#importing nba API

from nba_api.stats.static import teams

# %%
#returns id related to each team

nba_teams = teams.get_teams()
nba_teams[0:3]
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970}]

# %%
dict_nba_team  = one_dict(nba_teams)
df.teams = pd.DataFrame(dict_nba_team)
df.teams.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   from ipykernel import kernelapp as app
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Atlanta          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
df.warriors= df.teams[df.teams["nickname"]=="Warriors"]
df.warriors
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   if __name__ == '__main__':
#            id              full_name abbreviation  nickname          city  \
# 7  1610612744  Golden State Warriors          GSW  Warriors  Golden State
#
#         state  year_founded
# 7  California          1946

# %%
#type(df.warriors)
id_warriors =df.warriors[["id"]].values[0][0]
id_warriors
# Out:
# 1610612744

# %%
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullabe = id_warriors)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-ceec782e0cf3> in <module>
#       1 from nba_api.stats.endpoints import leaguegamefinder
# ----> 2 gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullabe = id_warriors)
#
# TypeError: __init__() got an unexpected keyword argument 'team_id_nullabe'

# %%
gamefinder = get_json()

# %%
! wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%205/Labs/Golden_State.pkl

# %%
import pandas as pd
file_name = "Golden_State.pk1"
games = pd.read_pickle(file_name)
games.head()
