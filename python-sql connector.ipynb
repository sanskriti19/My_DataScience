# %%
# !pip install mysql-connector-python

# %%
import mysql.connector
import pandas as pd

# %%
con = mysql.connector.connect(
host = 'localhost',
port =3306,
user = 'root',
password = 'sanskriti',
database = 'world')

df = pd.read_sql_query("select * from countrylanguage", con)
df.head(7)
# Out:
#   CountryCode    Language IsOfficial  Percentage
# 0         ABW       Dutch          T         5.3
# 1         ABW     English          F         9.5
# 2         ABW  Papiamento          F        76.7
# 3         ABW     Spanish          F         7.4
# 4         AFG     Balochi          F         0.9
# 5         AFG        Dari          T        32.1
# 6         AFG      Pashto          T        52.4

# %%
def q(s):
    df= pd.read_sql_query(s,con)
    return(df.head(5))
s = "select * from country"
q(s)
# Out:
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
# 2  AGO       Angola         Africa             Central Africa    1246700.0
# 3  AIA     Anguilla  North America                  Caribbean         96.0
# 4  ALB      Albania         Europe            Southern Europe      28748.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
# 2     1975.0    12878000            38.3  6648.0  7984.0
# 3        NaN        8000            76.1    63.2     NaN
# 4     1912.0     3401200            71.6  3205.0  2500.0
#
#                LocalName                                GovernmentForm  \
# 0                  Aruba  Nonmetropolitan Territory of The Netherlands
# ...

# %%
# !pip install SQLAlchemy

# %%
from sqlalchemy import create_engine
import pandas as pd
import mysql.connector

# %%
create= create_engine("mysql+mysqlconnector://root:"+'sanskriti'+'@localhost/world')

# %%
df= pd.read_sql_table("country",create)
df.head(6)
# Out:
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
# 2  AGO       Angola         Africa             Central Africa    1246700.0
# 3  AIA     Anguilla  North America                  Caribbean         96.0
# 4  ALB      Albania         Europe            Southern Europe      28748.0
# 5  AND      Andorra         Europe            Southern Europe        468.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
# 2     1975.0    12878000            38.3  6648.0  7984.0
# 3        NaN        8000            76.1    63.2     NaN
# 4     1912.0     3401200            71.6  3205.0  2500.0
# 5     1278.0       78000            83.5  1630.0     NaN
#
# ...

# %%
pd.read_sql_table?

# %%
df = pd.read_sql_table("country",create, columns=["Continent"])
df.head
# Out:
# <bound method NDFrame.head of          Continent
# 0    North America
# 1             Asia
# 2           Africa
# 3    North America
# 4           Europe
# ..             ...
# 234           Asia
# 235         Europe
# 236         Africa
# 237         Africa
# 238         Africa
#
# [239 rows x 1 columns]>

# %%
# practise on my created database

# %%
import mysql.connector
from sqlalchemy import create_engine
import pandas as pd

# %%
con = mysql.connector.connect(host = 'localhost',
                             port= 3306,
                             user = 'root',
                             password=  'sanskriti',
                             database = 'python')
df = pd.read_sql_query("select * from emp",con)
df.head(6)
# Out:
#    eid    name  did        city
# 0    1    sans  101    gurugram
# 1    2  sangam  102  khalilabad
# 2    3    amit  101     notanwa
# 3    4  adamya  104  khalilabad
# 4    5    rini  102   gorakhpur

# %%
def q(s):
    df=pd.read_sql_query(s,con)
    return df.head(6)
q("select * from emp where did = (select did from dept where name = 'software')")
# Out:
#    eid  name  did      city
# 0    1  sans  101  gurugram
# 1    3  amit  101   notanwa

# %%
con= create_engine("mysql+mysqlconnector://root:"+"sanskriti"+"@localhost/python")
df = pd.read_sql_table("dept",con,columns = ['did'])
df.head()
# Out:
#    did
# 0  101
# 1  102
# 2  103
# 3  104

# %%
df1 = pd.read_csv("C:\python practise\csv\dept.csv",names = ["did","names"])
df1.head()
# Out:
#    did        names
# 0  106    "support"
# 1  107    "testing"
# 2  108  "developer"
# 3  109  "front end"
# 4  110        "dba"
